# %%
import pandas as pd

# %%
dataframe = pd.read_csv("https://raw.githubusercontent.com/pywaker/datascience/master/Data/Pokemon.csv")

# %%
dataframe
# Out:
#        #                       Name    Type 1  Type 2  Total   HP  Attack  \
# 0      1                  Bulbasaur     Grass  Poison    318   45      49
# 1      2                    Ivysaur     Grass  Poison    405   60      62
# 2      3                   Venusaur     Grass  Poison    525   80      82
# 3      3      VenusaurMega Venusaur     Grass  Poison    625   80     100
# 4      4                 Charmander      Fire     NaN    309   39      52
# 5      5                 Charmeleon      Fire     NaN    405   58      64
# 6      6                  Charizard      Fire  Flying    534   78      84
# 7      6  CharizardMega Charizard X      Fire  Dragon    634   78     130
# 8      6  CharizardMega Charizard Y      Fire  Flying    634   78     104
# 9      7                   Squirtle     Water     NaN    314   44      48
# 10     8                  Wartortle     Water     NaN    405   59      63
# 11     9                  Blastoise     Water     NaN    530   79      83
# ...

# %%
dataframe.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
dataframe.tail()
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 795  719              Diancie     Rock  Fairy    600  50     100      150
# 796  719  DiancieMega Diancie     Rock  Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %%
dataframe.tail(10)
# Out:
#        #                 Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 790  714               Noibat   Flying  Dragon    245   40      30       35
# 791  715              Noivern   Flying  Dragon    535   85      70       80
# 792  716              Xerneas    Fairy     NaN    680  126     131       95
# 793  717              Yveltal     Dark  Flying    680  126     131       95
# 794  718     Zygarde50% Forme   Dragon  Ground    600  108     100      121
# 795  719              Diancie     Rock   Fairy    600   50     100      150
# 796  719  DiancieMega Diancie     Rock   Fairy    700   50     160      110
# 797  720  HoopaHoopa Confined  Psychic   Ghost    600   80     110       60
# 798  720   HoopaHoopa Unbound  Psychic    Dark    680   80     160       60
# 799  721            Volcanion     Fire   Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 790       45       40     55           6      False
# ...

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
# #             800 non-null int64
# Name          800 non-null object
# Type 1        800 non-null object
# Type 2        414 non-null object
# Total         800 non-null int64
# HP            800 non-null int64
# Attack        800 non-null int64
# Defense       800 non-null int64
# Sp. Atk       800 non-null int64
# Sp. Def       800 non-null int64
# Speed         800 non-null int64
# Generation    800 non-null int64
# Legendary     800 non-null bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
dataframe[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-db276f7d677e> in <module>
# ----> 1 dataframe[0]
#
# ...

# %%
dataframe["#"]
# Out:
# 0        1
# 1        2
# 2        3
# 3        3
# 4        4
# 5        5
# 6        6
# 7        6
# 8        6
# 9        7
# 10       8
# 11       9
# 12       9
# 13      10
# 14      11
# 15      12
# 16      13
# 17      14
# 18      15
# 19      15
# 20      16
# 21      17
# 22      18
# 23      18
# 24      19
# 25      20
# 26      21
# 27      22
# 28      23
# 29      24
#       ...
# 770    700
# 771    701
# 772    702
# 773    703
# 774    704
# 775    705
# 776    706
# 777    707
# 778    708
# 779    709
# 780    710
# 781    710
# 782    710
# 783    710
# 784    711
# 785    711
# 786    711
# 787    711
# 788    712
# 789    713
# 790    714
# 791    715
# 792    716
# 793    717
# 794    718
# 795    719
# 796    719
# 797    720
# 798    720
# 799    721
# Name: #, Length: 800, dtype: int64

# %%
dataframe["Name"]
# Out:
# 0                      Bulbasaur
# 1                        Ivysaur
# 2                       Venusaur
# 3          VenusaurMega Venusaur
# 4                     Charmander
# 5                     Charmeleon
# 6                      Charizard
# 7      CharizardMega Charizard X
# 8      CharizardMega Charizard Y
# 9                       Squirtle
# 10                     Wartortle
# 11                     Blastoise
# 12       BlastoiseMega Blastoise
# 13                      Caterpie
# 14                       Metapod
# 15                    Butterfree
# 16                        Weedle
# 17                        Kakuna
# 18                      Beedrill
# 19         BeedrillMega Beedrill
# 20                        Pidgey
# 21                     Pidgeotto
# 22                       Pidgeot
# 23           PidgeotMega Pidgeot
# 24                       Rattata
# 25                      Raticate
# 26                       Spearow
# 27                        Fearow
# ...

# %%
dataframe[1:5]
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
dataframe[["#", "Name"]]
# Out:
#        #                       Name
# 0      1                  Bulbasaur
# 1      2                    Ivysaur
# 2      3                   Venusaur
# 3      3      VenusaurMega Venusaur
# 4      4                 Charmander
# 5      5                 Charmeleon
# 6      6                  Charizard
# 7      6  CharizardMega Charizard X
# 8      6  CharizardMega Charizard Y
# 9      7                   Squirtle
# 10     8                  Wartortle
# 11     9                  Blastoise
# 12     9    BlastoiseMega Blastoise
# 13    10                   Caterpie
# 14    11                    Metapod
# 15    12                 Butterfree
# 16    13                     Weedle
# 17    14                     Kakuna
# 18    15                   Beedrill
# 19    15      BeedrillMega Beedrill
# 20    16                     Pidgey
# 21    17                  Pidgeotto
# 22    18                    Pidgeot
# 23    18        PidgeotMega Pidgeot
# 24    19                    Rattata
# ...

# %%
dataframe[:]
# Out:
#        #                       Name    Type 1  Type 2  Total   HP  Attack  \
# 0      1                  Bulbasaur     Grass  Poison    318   45      49
# 1      2                    Ivysaur     Grass  Poison    405   60      62
# 2      3                   Venusaur     Grass  Poison    525   80      82
# 3      3      VenusaurMega Venusaur     Grass  Poison    625   80     100
# 4      4                 Charmander      Fire     NaN    309   39      52
# 5      5                 Charmeleon      Fire     NaN    405   58      64
# 6      6                  Charizard      Fire  Flying    534   78      84
# 7      6  CharizardMega Charizard X      Fire  Dragon    634   78     130
# 8      6  CharizardMega Charizard Y      Fire  Flying    634   78     104
# 9      7                   Squirtle     Water     NaN    314   44      48
# 10     8                  Wartortle     Water     NaN    405   59      63
# 11     9                  Blastoise     Water     NaN    530   79      83
# ...

# %%
dataframe[:, "Name"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-cc022584a6eb> in <module>
# ----> 1 dataframe[:, "Name"]
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# C:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2655                                  'backfill or nearest lookups')
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#    2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#
# ...

# %%
dataframe.loc?
# Out:
# Type:        property
# String form: <property object at 0x0000000008420098>
# Docstring:
# Access a group of rows and columns by label(s) or a boolean array.
#
# ``.loc[]`` is primarily label based, but may also be used with a
# boolean array.
#
# Allowed inputs are:
#
# - A single label, e.g. ``5`` or ``'a'``, (note that ``5`` is
#   interpreted as a *label* of the index, and **never** as an
#   integer position along the index).
# - A list or array of labels, e.g. ``['a', 'b', 'c']``.
# - A slice object with labels, e.g. ``'a':'f'``.
#
#   .. warning:: Note that contrary to usual python slices, **both** the
#       start and the stop are included
#
# - A boolean array of the same length as the axis being sliced,
#   e.g. ``[True, False, True]``.
# - A ``callable`` function with one argument (the calling Series, DataFrame
#   or Panel) and that returns valid output for indexing (one of the above)
#
# See more at :ref:`Selection by Label <indexing.label>`
#
# Raises
# ------
# ...

# %%
dataframe.iloc?
# Out:
# Type:        property
# String form: <property object at 0x0000000008420048>
# Docstring:
# Purely integer-location based indexing for selection by position.
#
# ``.iloc[]`` is primarily integer position based (from ``0`` to
# ``length-1`` of the axis), but may also be used with a boolean
# array.
#
# Allowed inputs are:
#
# - An integer, e.g. ``5``.
# - A list or array of integers, e.g. ``[4, 3, 0]``.
# - A slice object with ints, e.g. ``1:7``.
# - A boolean array.
# - A ``callable`` function with one argument (the calling Series, DataFrame
#   or Panel) and that returns valid output for indexing (one of the above).
#   This is useful in method chains, when you don't have a reference to the
#   calling object, but would like to base your selection on some value.
#
# ``.iloc`` will raise ``IndexError`` if a requested indexer is
# out-of-bounds, except *slice* indexers which allow out-of-bounds
# indexing (this conforms with python/numpy *slice* semantics).
#
# ...

# %%
dataframe.loc[:]
# Out:
#        #                       Name    Type 1  Type 2  Total   HP  Attack  \
# 0      1                  Bulbasaur     Grass  Poison    318   45      49
# 1      2                    Ivysaur     Grass  Poison    405   60      62
# 2      3                   Venusaur     Grass  Poison    525   80      82
# 3      3      VenusaurMega Venusaur     Grass  Poison    625   80     100
# 4      4                 Charmander      Fire     NaN    309   39      52
# 5      5                 Charmeleon      Fire     NaN    405   58      64
# 6      6                  Charizard      Fire  Flying    534   78      84
# 7      6  CharizardMega Charizard X      Fire  Dragon    634   78     130
# 8      6  CharizardMega Charizard Y      Fire  Flying    634   78     104
# 9      7                   Squirtle     Water     NaN    314   44      48
# 10     8                  Wartortle     Water     NaN    405   59      63
# 11     9                  Blastoise     Water     NaN    530   79      83
# ...

# %%
dataframe.loc[2:8, ["#", "Name"]]
# Out:
#    #                       Name
# 2  3                   Venusaur
# 3  3      VenusaurMega Venusaur
# 4  4                 Charmander
# 5  5                 Charmeleon
# 6  6                  Charizard
# 7  6  CharizardMega Charizard X
# 8  6  CharizardMega Charizard Y

# %%
dataframe.loc[2:8, "Name": "HP"]
# Out:
#                         Name Type 1  Type 2  Total  HP
# 2                   Venusaur  Grass  Poison    525  80
# 3      VenusaurMega Venusaur  Grass  Poison    625  80
# 4                 Charmander   Fire     NaN    309  39
# 5                 Charmeleon   Fire     NaN    405  58
# 6                  Charizard   Fire  Flying    534  78
# 7  CharizardMega Charizard X   Fire  Dragon    634  78
# 8  CharizardMega Charizard Y   Fire  Flying    634  78

# %%
dataframe.iloc[2:8, 1:5]
# Out:
#                         Name Type 1  Type 2  Total
# 2                   Venusaur  Grass  Poison    525
# 3      VenusaurMega Venusaur  Grass  Poison    625
# 4                 Charmander   Fire     NaN    309
# 5                 Charmeleon   Fire     NaN    405
# 6                  Charizard   Fire  Flying    534
# 7  CharizardMega Charizard X   Fire  Dragon    634

# %%
dataframe.loc["Type 2"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Type 2'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-88bffb954ac0> in <module>
# ----> 1 dataframe.loc["Type 2"]
#
# C:\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1498
# ...

# %%
dataframe.loc[:, "Type 2"]
# Out:
# 0      Poison
# 1      Poison
# 2      Poison
# 3      Poison
# 4         NaN
# 5         NaN
# 6      Flying
# 7      Dragon
# 8      Flying
# 9         NaN
# 10        NaN
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15     Flying
# 16     Poison
# 17     Poison
# 18     Poison
# 19     Poison
# 20     Flying
# 21     Flying
# 22     Flying
# 23     Flying
# 24        NaN
# 25        NaN
# 26     Flying
# 27     Flying
# 28        NaN
# 29        NaN
#         ...
# 770       NaN
# 771    Flying
# 772     Fairy
# 773     Fairy
# 774       NaN
# 775       NaN
# 776       NaN
# 777     Fairy
# 778     Grass
# 779     Grass
# 780     Grass
# 781     Grass
# 782     Grass
# 783     Grass
# 784     Grass
# 785     Grass
# 786     Grass
# 787     Grass
# 788       NaN
# 789       NaN
# 790    Dragon
# 791    Dragon
# 792       NaN
# 793    Flying
# 794    Ground
# 795     Fairy
# 796     Fairy
# 797     Ghost
# 798      Dark
# 799     Water
# ...

# %%
dataframe["Type 2"].head()
# Out:
# 0    Poison
# 1    Poison
# 2    Poison
# 3    Poison
# 4       NaN
# Name: Type 2, dtype: object

# %%
dataframe["Type 2"].head() == "Poison"
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4    False
# Name: Type 2, dtype: bool

# %%
dataframe[dataframe["Type 2"] == "Poison"]
# Out:
#        #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass  Poison    318   45      49       49
# 1      2                Ivysaur  Grass  Poison    405   60      62       63
# 2      3               Venusaur  Grass  Poison    525   80      82       83
# 3      3  VenusaurMega Venusaur  Grass  Poison    625   80     100      123
# 16    13                 Weedle    Bug  Poison    195   40      35       30
# 17    14                 Kakuna    Bug  Poison    205   45      25       50
# 18    15               Beedrill    Bug  Poison    395   65      90       40
# 19    15  BeedrillMega Beedrill    Bug  Poison    495   65     150       40
# 48    43                 Oddish  Grass  Poison    320   45      50       55
# 49    44                  Gloom  Grass  Poison    395   60      65       70
# 50    45              Vileplume  Grass  Poison    490   75      80       85
# ...

# %%
mdf = dataframe[(dataframe["Type 2"] == "Poison") & (dataframe["Type 1"] == "Grass")]

# %%
mdf
# Out:
#        #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass  Poison    318   45      49       49
# 1      2                Ivysaur  Grass  Poison    405   60      62       63
# 2      3               Venusaur  Grass  Poison    525   80      82       83
# 3      3  VenusaurMega Venusaur  Grass  Poison    625   80     100      123
# 48    43                 Oddish  Grass  Poison    320   45      50       55
# 49    44                  Gloom  Grass  Poison    395   60      65       70
# 50    45              Vileplume  Grass  Poison    490   75      80       85
# 75    69             Bellsprout  Grass  Poison    300   50      75       35
# 76    70             Weepinbell  Grass  Poison    390   65      90       50
# 77    71             Victreebel  Grass  Poison    490   80     105       65
# 344  315                Roselia  Grass  Poison    400   50      60       45
# ...

# %%
mdf.loc[0]
# Out:
# #                     1
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# Total               318
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 0, dtype: object

# %%
mdf.loc[4]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 4
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-f6a06c3b7328> in <module>
# ----> 1 mdf.loc[4]
#
# ...

# %%
mdf.iloc[4]
# Out:
# #                 43
# Name          Oddish
# Type 1         Grass
# Type 2        Poison
# Total            320
# HP                45
# Attack            50
# Defense           55
# Sp. Atk           75
# Sp. Def           65
# Speed             30
# Generation         1
# Legendary      False
# Name: 48, dtype: object

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns
sns.set()

# %%
mdf[["Name", "Total"]].plot(kind="bar")

# %%
help(mdf[["Name", "Total"]].plot)
# Out:
# Help on FramePlotMethods in module pandas.plotting._core object:
#
# class FramePlotMethods(BasePlotMethods)
#  |  FramePlotMethods(data)
#  |
#  |  DataFrame plotting accessor and method
#  |
#  |  Examples
#  |  --------
#  |  >>> df.plot.line()
#  |  >>> df.plot.scatter('x', 'y')
#  |  >>> df.plot.hexbin()
#  |
#  |  These plotting methods can also be accessed by calling the accessor as a
#  |  method with the ``kind`` argument:
#  |  ``df.plot(kind='line')`` is equivalent to ``df.plot.line()``
#  |
#  |  Method resolution order:
#  |      FramePlotMethods
#  |      BasePlotMethods
#  |      pandas.core.base.PandasObject
#  |      pandas.core.base.StringMixin
#  |      pandas.core.accessor.DirNamesMixin
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
# ...

# %%
mdf[["Name", "Total"]].plot(kind="bar", x="Name", y="Total")

# %%
mdf
# Out:
#        #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass  Poison    318   45      49       49
# 1      2                Ivysaur  Grass  Poison    405   60      62       63
# 2      3               Venusaur  Grass  Poison    525   80      82       83
# 3      3  VenusaurMega Venusaur  Grass  Poison    625   80     100      123
# 48    43                 Oddish  Grass  Poison    320   45      50       55
# 49    44                  Gloom  Grass  Poison    395   60      65       70
# 50    45              Vileplume  Grass  Poison    490   75      80       85
# 75    69             Bellsprout  Grass  Poison    300   50      75       35
# 76    70             Weepinbell  Grass  Poison    390   65      90       50
# 77    71             Victreebel  Grass  Poison    490   80     105       65
# 344  315                Roselia  Grass  Poison    400   50      60       45
# ...

# %%
mdf.mean()
# Out:
# #             177.333333
# Total         414.066667
# HP             64.866667
# Attack         70.533333
# Defense        62.533333
# Sp. Atk        87.133333
# Sp. Def        75.333333
# Speed          53.666667
# Generation      2.066667
# Legendary       0.000000
# dtype: float64

# %%
mdf.sum()
# Out:
# #                                                          2660
# Name          BulbasaurIvysaurVenusaurVenusaurMega VenusaurO...
# Type 1        GrassGrassGrassGrassGrassGrassGrassGrassGrassG...
# Type 2        PoisonPoisonPoisonPoisonPoisonPoisonPoisonPois...
# Total                                                      6211
# HP                                                          973
# Attack                                                     1058
# Defense                                                     938
# Sp. Atk                                                    1307
# Sp. Def                                                    1130
# Speed                                                       805
# Generation                                                   31
# Legendary                                                 False
# dtype: object

# %%
mdf.mean
# Out:
# <bound method DataFrame.mean of        #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass  Poison    318   45      49       49
# 1      2                Ivysaur  Grass  Poison    405   60      62       63
# 2      3               Venusaur  Grass  Poison    525   80      82       83
# 3      3  VenusaurMega Venusaur  Grass  Poison    625   80     100      123
# 48    43                 Oddish  Grass  Poison    320   45      50       55
# 49    44                  Gloom  Grass  Poison    395   60      65       70
# 50    45              Vileplume  Grass  Poison    490   75      80       85
# 75    69             Bellsprout  Grass  Poison    300   50      75       35
# 76    70             Weepinbell  Grass  Poison    390   65      90       50
# 77    71             Victreebel  Grass  Poison    490   80     105       65
# 344  315                Roselia  Grass  Poison    400   50      60       45
# ...

# %%
len
# Out:
# <function len(obj, /)>

# %%
mdf.std()
# Out:
# #             219.726995
# Total         102.019933
# HP             19.164203
# Attack         20.476002
# Defense        22.727789
# Sp. Atk        22.481315
# Sp. Def        23.026899
# Speed          21.083733
# Generation      1.624221
# Legendary       0.000000
# dtype: float64

# %%
mdf.max()
# Out:
# #                    591
# Name          Weepinbell
# Type 1             Grass
# Type 2            Poison
# Total                625
# HP                   114
# Attack               105
# Defense              123
# Sp. Atk              125
# Sp. Def              120
# Speed                 90
# Generation             5
# Legendary          False
# dtype: object

# %%
mdf.min()
# Out:
# #                     1
# Name          Amoonguss
# Type 1            Grass
# Type 2           Poison
# Total               280
# HP                   40
# Attack               30
# Defense              35
# Sp. Atk              50
# Sp. Def              30
# Speed                15
# Generation            1
# Legendary         False
# dtype: object

# %%
mdf["HP"].max()
# Out:
# 114

# %%
mdf["HP"].idxmax()
# Out:
# 652

# %%
mdf.loc[mdf["HP"].idxmax()]
# Out:
# #                   591
# Name          Amoonguss
# Type 1            Grass
# Type 2           Poison
# Total               464
# HP                  114
# Attack               85
# Defense              70
# Sp. Atk              85
# Sp. Def              80
# Speed                30
# Generation            5
# Legendary         False
# Name: 652, dtype: object

# %%
dataframe["Attack"].min()
# Out:
# 5

# %%
ndf = dataframe[dataframe["Attack"] < 25]

# %%
ndf.head()
# Out:
#        #      Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 14    11   Metapod      Bug     NaN    205   50      20       55       25
# 68    63      Abra  Psychic     NaN    310   25      20       15      105
# 121  113   Chansey   Normal     NaN    450  250       5        5       35
# 139  129  Magikarp    Water     NaN    200   20      10       55       15
# 179  165    Ledyba      Bug  Flying    265   40      20       30       40
#
#      Sp. Def  Speed  Generation  Legendary
# 14        25     30           1      False
# 68        55     90           1      False
# 121      105     50           1      False
# 139       20     80           1      False
# 179       80     55           2      False

# %%
ndf.groupby(["Type 1"])

# %%
ndf2 = ndf.groupby(["Type 1"]).mean()

# %%
ndf2
# Out:
#               #   Total      HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1
# Bug      263.50  297.00   38.75   18.00    93.75    25.50    91.25  29.75
# Fairy    175.00  245.00   35.00   20.00    65.00    40.00    65.00  20.00
# Normal   265.60  330.00  142.00   12.00    19.00    33.00    78.00  46.00
# Psychic  211.50  285.00   60.00   21.50    31.50    64.00    51.50  56.50
# Steel    436.00  300.00   57.00   24.00    86.00    24.00    86.00  23.00
# Water    279.75  248.75   38.75   16.25    43.75    26.25    61.25  62.50
#
#          Generation  Legendary
# Type 1
# Bug            2.75      False
# Fairy          2.00      False
# Normal         2.40      False
# Psychic        2.00      False
# Steel          4.00      False
# Water          2.50      False

# %%
ndf2.iloc[0]
# Out:
# #             263.5
# Total           297
# HP            38.75
# Attack           18
# Defense       93.75
# Sp. Atk        25.5
# Sp. Def       91.25
# Speed         29.75
# Generation     2.75
# Legendary     False
# Name: Bug, dtype: object

# %%
ndf2.loc["Bug"]
# Out:
# #             263.5
# Total           297
# HP            38.75
# Attack           18
# Defense       93.75
# Sp. Atk        25.5
# Sp. Def       91.25
# Speed         29.75
# Generation     2.75
# Legendary     False
# Name: Bug, dtype: object

# %%
ndf2.plot(kind="bar", y="Attack")

# %%
ndf2.plot(kind="bar", y=["Attack", "Defense", "Speed"])

# %%
ax = ndf2.plot(kind="bar", y="Attack")
ndf2.plot(kind="bar", y="Defense", ax=ax, color="C2")
ndf2.plot(kind="bar", y="Speed", ax=ax, color="C3")

# %%
ax = ndf2.plot(kind="barh", y="Attack")
ndf2.plot(kind="barh", y="Defense", ax=ax, color="red")
ndf2.plot(kind="barh", y="Speed", ax=ax, color="cyan")

# %%
ndf3 = ndf.groupby(["Type 1", "Type 2"]).mean()

# %%
ndf3
# Out:
#                   #  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1 Type 2
# Bug    Flying   165    265  40      20       30       40       80     55
#        Rock     213    505  20      10      230       10      230      5
# Normal Fairy    298    190  50      20       40       20       40     20
# Steel  Psychic  436    300  57      24       86       24       86     23
# Water  Fairy    183    250  70      20       50       20       50     40
#        Flying   458    345  45      20       50       60      120     50
#
#                 Generation  Legendary
# Type 1 Type 2
# Bug    Flying            2      False
#        Rock              2      False
# Normal Fairy             3      False
# Steel  Psychic           4      False
# Water  Fairy             2      False
#        Flying            4      False

# %%
ndf3.loc["Bug"]
# Out:
#           #  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# Type 2
# Flying  165    265  40      20       30       40       80     55           2
# Rock    213    505  20      10      230       10      230      5           2
#
#         Legendary
# Type 2
# Flying      False
# Rock        False

# %%
ndf3.loc[("Bug", "Flying")]
# Out:
# #               165
# Total           265
# HP               40
# Attack           20
# Defense          30
# Sp. Atk          40
# Sp. Def          80
# Speed            55
# Generation        2
# Legendary     False
# Name: (Bug, Flying), dtype: object

# %%
ndf2
# Out:
#               #   Total      HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1
# Bug      263.50  297.00   38.75   18.00    93.75    25.50    91.25  29.75
# Fairy    175.00  245.00   35.00   20.00    65.00    40.00    65.00  20.00
# Normal   265.60  330.00  142.00   12.00    19.00    33.00    78.00  46.00
# Psychic  211.50  285.00   60.00   21.50    31.50    64.00    51.50  56.50
# Steel    436.00  300.00   57.00   24.00    86.00    24.00    86.00  23.00
# Water    279.75  248.75   38.75   16.25    43.75    26.25    61.25  62.50
#
#          Generation  Legendary
# Type 1
# Bug            2.75      False
# Fairy          2.00      False
# Normal         2.40      False
# Psychic        2.00      False
# Steel          4.00      False
# Water          2.50      False

# %%
import numpy as np

# %%
ndf2["HitPoint"] = np.NaN

# %%
ndf2
# Out:
#               #   Total      HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1
# Bug      263.50  297.00   38.75   18.00    93.75    25.50    91.25  29.75
# Fairy    175.00  245.00   35.00   20.00    65.00    40.00    65.00  20.00
# Normal   265.60  330.00  142.00   12.00    19.00    33.00    78.00  46.00
# Psychic  211.50  285.00   60.00   21.50    31.50    64.00    51.50  56.50
# Steel    436.00  300.00   57.00   24.00    86.00    24.00    86.00  23.00
# Water    279.75  248.75   38.75   16.25    43.75    26.25    61.25  62.50
#
#          Generation  Legendary  HitPoint
# Type 1
# Bug            2.75      False       NaN
# Fairy          2.00      False       NaN
# Normal         2.40      False       NaN
# Psychic        2.00      False       NaN
# Steel          4.00      False       NaN
# Water          2.50      False       NaN

# %%
ndf2["HitPoint"] = ndf2["Defense"] / ndf2["Attack"]

# %%
ndf2
# Out:
#               #   Total      HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1
# Bug      263.50  297.00   38.75   18.00    93.75    25.50    91.25  29.75
# Fairy    175.00  245.00   35.00   20.00    65.00    40.00    65.00  20.00
# Normal   265.60  330.00  142.00   12.00    19.00    33.00    78.00  46.00
# Psychic  211.50  285.00   60.00   21.50    31.50    64.00    51.50  56.50
# Steel    436.00  300.00   57.00   24.00    86.00    24.00    86.00  23.00
# Water    279.75  248.75   38.75   16.25    43.75    26.25    61.25  62.50
#
#          Generation  Legendary  HitPoint
# Type 1
# Bug            2.75      False  5.208333
# Fairy          2.00      False  3.250000
# Normal         2.40      False  1.583333
# Psychic        2.00      False  1.465116
# Steel          4.00      False  3.583333
# Water          2.50      False  2.692308

# %%
ndf2["Defense"] / ndf2["Attack"]
# Out:
# Type 1
# Bug        5.208333
# Fairy      3.250000
# Normal     1.583333
# Psychic    1.465116
# Steel      3.583333
# Water      2.692308
# dtype: float64
